# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import json
import numpy as np

# !pip install openai

# !pip install langchain
# !pip install huggingface_hub
# !pip install langchain-community langchain-core

# !pip install -q langchain
# !pip install -q torch
# !pip install -q transformers
# !pip install -q sentence-transformers
# !pip install -q datasets
# !pip install -q faiss-cpu
# !pip install langchainhub

from langchain.document_loaders import HuggingFaceDatasetLoader
from langchain.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS

from langchain.schema.runnable import RunnablePassthrough
from langchain.schema import StrOutputParser
from langchain import hub
from langchain.chat_models import ChatOpenAI
# Out:
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (1.109.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai) (4.11.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai) (0.12.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai) (2.11.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai) (0.4.2)
# Requirement already satisfied: langchain in /usr/local/lib/python3.12/dist-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.72 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.3.79)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.3.11)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain) (0.4.42)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.11.10)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.0.44)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langchain) (2.32.5)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.12/dist-packages (from langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (8.5.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.72->langchain) (24.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain) (2025.10.5)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.2.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.72->langchain) (3.0.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2.32.5)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2025.10.5)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.12/dist-packages (0.4.1)
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.12/dist-packages (0.3.79)
# Collecting langchain-core
#   Using cached langchain_core-1.0.4-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.42)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (2.11.10)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Collecting langchain-text-splitters<2.0.0,>=1.0.0 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Using cached langchain_text_splitters-1.0.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2025.10.5)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.11.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Using cached langchain_core-1.0.4-py3-none-any.whl (471 kB)
# Using cached langchain_text_splitters-1.0.0-py3-none-any.whl (33 kB)
# Installing collected packages: langchain-core, langchain-text-splitters
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.79
#     Uninstalling langchain-core-0.3.79:
#       Successfully uninstalled langchain-core-0.3.79
#   Attempting uninstall: langchain-text-splitters
#     Found existing installation: langchain-text-splitters 0.3.11
#     Uninstalling langchain-text-splitters-0.3.11:
#       Successfully uninstalled langchain-text-splitters-0.3.11
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.27 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.0.4 which is incompatible.
# langchain 0.3.27 requires langchain-text-splitters<1.0.0,>=0.3.9, but you have langchain-text-splitters 1.0.0 which is incompatible.
# Successfully installed langchain-core-1.0.4 langchain-text-splitters-1.0.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-classic 1.0.0 requires langchain-core<2.0.0,>=1.0.0, but you have langchain-core 0.3.79 which is incompatible.
# langchain-classic 1.0.0 requires langchain-text-splitters<2.0.0,>=1.0.0, but you have langchain-text-splitters 0.3.11 which is incompatible.
# langchain-community 0.4.1 requires langchain-core<2.0.0,>=1.0.1, but you have langchain-core 0.3.79 which is incompatible.
# Requirement already satisfied: langchainhub in /usr/local/lib/python3.12/dist-packages (0.1.21)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.12/dist-packages (from langchainhub) (24.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langchainhub) (2.32.5)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in /usr/local/lib/python3.12/dist-packages (from langchainhub) (2.32.4.20250913)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchainhub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchainhub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchainhub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchainhub) (2025.10.5)

# %% [markdown]
# Initialize the model

# %%
# Set the environment variables from shell environment
OPENAI_API_KEY = "..." # Your API key here

# Select a model
#OPENAI_CHAT_MODEL = "gpt-5-nano-2025-08-07"
#OPENAI_CHAT_MODEL = "gpt-5-mini-2025-08-07"
OPENAI_CHAT_MODEL = "gpt-5-2025-08-07"

model = OPENAI_CHAT_MODEL

# %% [markdown]
# Open the data

# %%
f = open("drive/MyDrive/data/defi-text-mine-egc-2026/train_v2.jsonl", "r")

text = []
acronyms = []
options = []

for line in f:
  try:
      data = json.loads(line)

      text.append(data["text"])

      acronyms.append(data["acronym"])

      options.append(data["options"])

  except ValueError:
      print('Invalid input:',line)

f.close()

# %% [markdown]
# # An LLM based approach

# %% [markdown]
# ### Setup RAG environment

# %% [markdown]
# Load external knowledge source:

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

fileName = "drive/MyDrive/data/defi-text-mine-egc-2026/lexique-des-acronymes-sncf.csv"

loader = CSVLoader(
    file_path=fileName,
    csv_args={
        "delimiter": ";",
        "quotechar": '"'
    },
    source_column="Abréviation"
)

data = loader.load()

# %%
print(data)
# Out:
# [Document(metadata={'source': 'CL', 'row': 0}, page_content='\ufeffid: 14556.0\nAbréviation: CL\nDéfinition: Caténaire Légère._x000D_\nCaractéristiques : porteur principal (65mmÂ² bronze) + 1 fil de contact (107mmÂ² cuivre) caténaire 1500V\nempty: '), Document(metadata={'source': 'CMAU', 'row': 1}, page_content="\ufeffid: 4567.0\nAbréviation: CMAU\nDéfinition: Centre multi-régional d'appui aux utilisateurs du sirh\nempty: "), Document(metadata={'source': 'CNMHS', 'row': 2}, page_content='\ufeffid: 9606.0\nAbréviation: CNMHS\nDéfinition: Commission nationale mixte hygiène et sécurité\nempty: '), Document(metadata={'source': 'COT LIGNE D', 'row': 3}, page_content="\ufeffid: 905.0\nAbréviation: COT LIGNE D\nDéfinition: (anciennement CLD : Chef de la Ligne D) : Centre Opérationnel Transilien Ligne D. Situé à\xa0 proximité du régulateur de Paris-Sud-Est, les agents du COT ont pour mission de faire circuler les informations aux postes, d'assurer le suivi des rames (révisions, pannes...), des trains et des agents en service. Il gère toutes les circulations sur les lignes D, R et quelques TER Bourgogne assurés par du matériel Z5300 et Z2N (avec l'aval des régulateurs, car les voies ne sont pas dédiées uniquement aux trains de la banlieue).\nempty: "), Document(metadata={'source': 'CYA', 'row': 4}, page_content='\ufeffid: 1019.0\nAbréviation: CYA\nDéfinition: Chepy Valines (Gare)\nempty: '), Document(metadata={'source': 'CYB', 'row': 5}, page_content='\ufeffid: 1020.0\nAbréviation: CYB\nDéfinition: La Clayette-Baudemont (Gare)\nempty: '), Document(metadata={'source': 'CZD', 'row': 6}, page_content='\ufeffid: 1037.0\nAbréviation: CZD\nDéfinition: Couze (Gare)\nempty: '), Document(metadata={'source': 'CZN', 'row': 7}, page_content='\ufeffid: 1041.0\nAbréviation: CZN\nDéfinition: Coarraze Nay (Gare)\nempty: '), Document(metadata={'source': 'DAB', 'row': 8}, page_content='\ufeffid: 12146.0\nAbréviation: DAB\nDéfinition: Distributeur automatique de billets de banque\nempty: '), Document(metadata={'source': 'DAR', 'row': 9}, page_content="\ufeffid: 4699.0\nAbréviation: DAR\nDéfinition: Direction de l'audit et des risques\nempty: "), Document(metadata={'source': 'DET', 'row': 10}, page_content="\ufeffid: 4749.0\nAbréviation: DET\nDéfinition: Direction de l'exécution des contrats de travaux\nempty: "), Document(metadata={'source': 'DGGN', 'row': 11}, page_content='\ufeffid: 4758.0\nAbréviation: DGGN\nDéfinition: Direction générale de la gendarmerie nationale\nempty: '), Document(metadata={'source': 'LX', 'row': 12}, page_content='\ufeffid: 7408.0\nAbréviation: LX\nDéfinition: Lumineux\nempty: '), Document(metadata={'source': 'VET', 'row': 13}, page_content='\ufeffid: 3610.0\nAbréviation: VET\nDéfinition: VERNOUILLET VERNEUIL (GARE)\nempty: '), Document(metadata={'source': 'VSA', 'row': 14}, page_content='\ufeffid: 3706.0\nAbréviation: VSA\nDéfinition: VIC-SUR-AISNE (GARE)\nempty: '), Document(metadata={'source': 'ZIF', 'row': 15}, page_content="\ufeffid: 8433.0\nAbréviation: ZIF\nDéfinition: Zero insertion force ( support permettant l'installation/enlèvement d'un composant électronique sans forcer)\nempty: "), Document(metadata={'source': 'MHY', 'row': 16}, page_content='\ufeffid: 2204.0\nAbréviation: MHY\nDéfinition: MEHUN SUR YEVRE (GARE)\nempty: '), Document(metadata={'source': 'SM', 'row': 17}, page_content='\ufeffid: 5674.0\nAbréviation: SM\nDéfinition: Service mécanique : assure la maintenance de la signalisation mécanique\nempty: '), Document(metadata={'source': 'SOB', 'row': 18}, page_content='\ufeffid: 3247.0\nAbréviation: SOB\nDéfinition: ST OUEN DU BREUIL (GARE)\nempty: '), Document(metadata={'source': 'SOP', 'row': 19}, page_content='\ufeffid: 3257.0\nAbréviation: SOP\nDéfinition: SOSPEL (GARE)\nempty: '), Document(metadata={'source': 'TLP', 'row': 20}, page_content='\ufeffid: 3478.0\nAbréviation: TLP\nDéfinition: TRILPORT (GARE)\nempty: '), Document(metadata={'source': 'TRANSCARTE', 'row': 21}, page_content='\ufeffid: 5810.0\nAbré ...

# %%
len(data)
# Out:
# 9502

# %%
print(data[10].page_content)
# Out:
# ﻿id: 4749.0
# Abréviation: DET
# Définition: Direction de l'exécution des contrats de travaux
# empty:

# %% [markdown]
# Compute the embeddings:

# %%
# Define the path to the pre-trained model you want to use
#modelPath = "sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2"
modelPath = "intfloat/multilingual-e5-base"

# Create a dictionary with model configuration options, specifying to use the CPU for computations
model_kwargs = {'device':'cpu'}

# Create a dictionary with encoding options, specifically setting 'normalize_embeddings' to False
encode_kwargs = {'normalize_embeddings': False}

# Initialize an instance of HuggingFaceEmbeddings with the specified parameters
embeddings = HuggingFaceEmbeddings(
    model_name=modelPath,     # Provide the pre-trained model's path
    model_kwargs=model_kwargs, # Pass the model configuration options
    encode_kwargs=encode_kwargs # Pass the encoding options
)
# Out:
# /tmp/ipython-input-1677010703.py:13: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/387 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/57.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/694 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/200 [00:00<?, ?B/s]

# %% [markdown]
# Define database for storing embeddings:

# %%
db = FAISS.from_documents(data, embeddings)

# %% [markdown]
# ### Querry ChatGPT-5

# %% [markdown]
# Define query retriever:

# %%
retriever = db.as_retriever(search_kwargs={"k": 3}) # Select top k similar documents

# %% [markdown]
# Define a RAG pipeline:

# %%
rag_chain = (
    {"context": retriever, "question": RunnablePassthrough()}
    | hub.pull("rlm/rag-prompt")
    | ChatOpenAI(model_name=OPENAI_CHAT_MODEL, temperature=1, openai_api_key=OPENAI_API_KEY)
    | StrOutputParser()
)

# %% [markdown]
# Function to post-process the results:

# %%
import re
import ast

def extract_bool_list(text):
    """Return a list of all boolean lists found in `text`.
       Example: ' [ASSISTANT] [False, True]' -> [[False, True]]"""
    text = text.replace('"','').replace("'","") # get rid of all quotes
    candidates = re.findall(r'\[.*?\]', text)  # non-greedy bracket matches
    results = []
    for cand in candidates:
        # normalize lowercase true/false to Python booleans (optional)
        cand_norm = re.sub(r'\btrue\b', 'True', cand, flags=re.IGNORECASE)
        cand_norm = re.sub(r'\bfalse\b', 'False', cand_norm, flags=re.IGNORECASE)

        try:
            val = ast.literal_eval(cand_norm)
        except Exception:
            # not a Python literal (e.g. [ASSISTANT]) -> skip
            continue

        # keep only lists made entirely of booleans
        if isinstance(val, list) and all(isinstance(x, bool) for x in val):
            results.append(val)

    return results[0] if results else None

# %% [markdown]
# Perform prediction (on a train set!)

# %%
result_dic = {}
examples_to_process = [(i,0) for i in range(len(text))]

flag = False
count = 0
while examples_to_process != []:
  if count % 10 == 0:
    print(len(examples_to_process))

  item = examples_to_process.pop(0)

  # Querry the LLM
  response = rag_chain.invoke("Find what is "+acronyms[item[0]]+" in this phrase: "+text[item[0]]+". Evaluate the following options by giving the boolean list as an answer: "+str([j for j in options[item[0]].keys()])+". Output only the boolean list. Do not output any explanation nor other text")

  # Post-process result
  labels_pred = extract_bool_list(response)
  if labels_pred != None:
    if len(labels_pred) == len(options[item[0]]):
      result_dic[item[0]] = (labels_pred,item[1])
    else:
      flag = True
  else:
    flag = True

  if flag:
    if item[1] < 1:
      examples_to_process.append((item[0],item[1]+1))
    flag = False
  count+=1
# Out:
# 491
# 481
# 471
# 461
# 451
# 441
# 431
# 421
# 411
# 401
# 391
# 381
# 371
# 361
# 351
# 341
# 331
# 321
# 311
# 301
# 291
# 281
# 271
# 261
# 251
# 241
# 231
# 221
# 211
# 201
# 191
# 181
# 171
# 161
# 151
# 141
# 131
# 121
# 111
# 101
# 91
# 81
# 71
# 61
# 51
# 41
# 31
# 21
# 11
# 1

# %% [markdown]
# Predicted labels

# %%
count
# Out:
# 492

# %%
result_dic
# Out:
# {0: ([False, True, False, False], 0),
#  1: ([True, False, False, False, False, False, True], 0),
#  2: ([False, True, False, False, False, False], 0),
#  3: ([False, False, False, False, False, False, False, False, True, False], 0),
#  4: ([False, False, True], 0),
#  5: ([True, False], 0),
#  6: ([False, True], 0),
#  7: ([True, False], 0),
#  8: ([False, False, False, False, False, False, True], 0),
#  9: ([False, True, False, False], 0),
#  10: ([False, True], 0),
#  11: ([False, False, True, False], 0),
#  12: ([False, True], 0),
#  13: ([False, False, False, False, False, True], 0),
#  14: ([True, False], 0),
#  15: ([False, True, False, False], 0),
#  16: ([True, False, False, False], 0),
#  17: ([True, False, False], 0),
#  18: ([True, False, False, False, False, False], 0),
#  19: ([False, True], 0),
#  20: ([True, False, False, False, False, False, False, False, False, False],
#   0),
#  21: ([True, False, False], 0),
#  22: ([False, False, False, True, False, False], 0),
#  23: ([False, True], 0),
#  24: ([False, True, False, False, False, False], 0),
#  25: ([False, False, False, True, False, False], 0),
#  26: ([False, False, False, False, False, False, True, False, False, False],
#   0),
#  27: ([False, True, False, False, False, False], 0),
#  28: ([True, False, False], 0),
#  29: ([False, False, True, False, False, False], 0),
#  30: ([False, False, False, False, False, False], 0),
#  31: ([False, False, True, False, False, False], 0),
#  32: ([False, False, False, True, False, False, False, False, False], 0),
#  33: ([False, False, True], 0),
#  34: ([False, False, True], 0),
#  35: ([False, False, True, False], 0),
#  36: ([True, False], 0),
#  37: ([False, True, False], 0),
#  38: ([False, False, False, False, False, False, False, True], 0),
#  39: ([False, True], 0),
#  40: ([False, False, True, False], 0),
#  41: ([True, False], 0),
#  42: ([False, True], 0),
#  43: ([False, True, False, False, False, False], 0),
#  44: ([False, False, False, False, True, False], 0),
#  45: ([False, True, False], 0),
#  46: ([False, False, False, False, False, True, False], 0),
#  47: ([False, True, False, False, False, False, False], 0),
#  48: ([False, True], 0),
#  49: ([True, False], 0),
#  50: ([False, True, False, False], 0),
#  51: ([True, False, False, False, False, True, False], 0),
#  52: ([False, True, False, False], 0),
#  53: ([False, True], 0),
#  54: ([False, True, False, False, False, False], 0),
#  55: ([False, False, True, False, False, False], 0),
#  56: ([True, False, False, False, False, False, False], 0),
#  57: ([True, False, False], 0),
#  58: ([True, False], 0),
#  59: ([True, False], 0),
#  60: ([False, True], 0),
#  61: ([False, False, False, False, False, True, False], 0),
#  62: ([False, True, False, False], 0),
#  63: ([False, False, True], 0),
#  64: ([False, False, False, False, True, False], 0),
#  65: ([False, False, True, False, False, False], 0),
#  66: ([False, False, False, False, True], 0),
#  67: ([False, True, False], 0),
#  68: ([False, False, False, False, True, False], 0),
#  69: ([True, True, False, True], 0),
#  70: ([False, False, False, False, True, False], 0),
#  71: ([True, False, False, False, False, False, True], 0),
#  72: ([False, False, True, False, False, False, False], 0),
#  73: ([False, True, False, False, False, False, False, False, False, False],
#   0),
#  74: ([True, False, False, False], 0),
#  75: ([False, True, False, False, False], 0),
#  76: ([False, False, False, False, False, False, False, False, False, True],
#   0),
#  77: ([False, False, True, False, False, False], 0),
#  78: ([False, True], 0),
#  79: ([False, True], 0),
#  80: ([False, True, False, False], 0),
#  81: ([True, False, False, False, False, False], 0),
#  82: ([False, True], 0),
#  83: ([False, False, False, False, True, False, False, False, False], 0),
#  84: ([False, False, True, False, False, False, False], 0),
#  85: ([False, True, False, False, False, False], 0),
#  86: ([False, False, False, False, True, False], 0),
#  87: ([False, False, False, True, False, False], 0),
#  88: ([False, False, False, False, False, True], 0),
#  89: ([True, False], 0),
#  90: ([False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False],
#   0),
#  91: ([True, False, False, False, False, False], 0),
#  92: ([True, False, False], 0),
#  93: ([True, False], 0),
#  94: ([False, False, True], 0),
#  95: ([False, False, False, False, True, False], 0),
#  96: ([True, False, False, False, False], 0),
#  97: ([False, False, True], 0),
#  98: ([False, False, False, False, True, False, False, False, False, False],
#   0),
#  99: ([True, False, False, False], 0),
#  100: ([False, True, False], 0),
#  101: ([True, False, False, False, False, False], 0),
#  102: ([True, False, False], 0),
#  103: ([False, False, False, True], 0),
#  104: ([False, False, True, False, False, False], 0),
#  105: ([True, True, False, False], 0),
#  106: ([False, True], 0),
#  107: ([True, False], 0),
#  108: ([True, False, False], 0),
#  109: ([False, False, False, False, False, False], 0),
#  110: ([False, False, True, False], 0),
#  111: ([False, False, False, False, False, False, True, False, False, False],
#   0),
#  112: ([False, True, False, False, False, False], 0),
#  113: ([True, False, False, False, False, False], 0),
#  114: ([True, False, False], 0),
#  115: ([False, False, False, False, False, True, False], 0),
#  116: ([True, False], 0),
#  117: ([False, True, False, False], 0),
#  118: ([False, False, False, False, False, True], 0),
#  119: ([True, False], 0),
#  120: ([False, True], 0),
#  121: ([True, False], 0),
#  122: ([False, False, True, False, False, False], 0),
#  123: ([False, True], 0),
#  124: ([False, True, False, False, False, False], 0),
#  125: ([False, False, False, False, True, False, False, False, False, False],
#   0),
#  126: ([False, False, True, False, False, False, False, False, False, False],
#   0),
#  127: ([True, False, False], 0),
#  128: ([False, False, True, False], 0),
#  129: ([True, False, False, False], 0),
#  130: ([False, True], 0),
#  131: ([False, False, False, False, True], 0),
#  132: ([True, False, False, False, False, False, False, False, False, False],
#   0),
#  133: ([True, False], 0),
#  134: ([False, False, True], 0),
#  135: ([False, False, False, False, False, False, True, False], 0),
#  136: ([False, False, True, False, False, False], 0),
#  137: ([True, False], 0),
#  138: ([False, False, False, True], 0),
#  139: ([False, True, True, False], 0),
#  140: ([False, False], 0),
#  141: ([False, True, True, False], 0),
#  142: ([False, False, False, False, False, False, True, False, False, False],
#   0),
#  143: ([False, False, False, False, False, False, True], 0),
#  144: ([False, True], 0),
#  145: ([True, False], 0),
#  146: ([False, False, True, False, False, False], 0),
#  147: ([False, True, False, False], 0),
#  148: ([True, False], 0),
#  149: ([True, False], 0),
#  150: ([False, False, False, False, False, False, True], 0),
#  151: ([False, False, False, False, False, True], 0),
#  152: ([True, False, False], 0),
#  153: ([False, False, True, False], 0),
#  154: ([True, False, False, False, False, False, False], 0),
#  155: ([False, False, True, False], 0),
#  156: ([False, True], 0),
#  157: ([False, False, False, False, False, False, False, True, False, False],
#   0),
#  158: ([True, False, False, False, False, False], 0),
#  159: ([True, False, False, False], 0),
#  160: ([False, False, False, False, False], 0),
#  161: ([False, False, False, False, True, False, False, False, False, False],
#   0),
#  162: ([False, True], 0),
#  163: ([True, False], 0),
#  164: ([True, False, False, False, False, False, True], 0),
#  165: ([False, False, True, False, False, False, False, False, False, False],
#   0),
#  166: ([True, False], 0),
#  167: ([False, False, True, True], 0),
#  168: ([False, False, True, False], 0),
#  169: ([True, False], 0),
#  170: ([True, False, False], 0),
#  171: ([False, True, False], 0),
#  172: ([False, True, False, False, False, False], 0),
#  173: ([False, False, False, False, False, True], 0),
#  174: ([True, False], 0),
#  175: ([True, False, False, False, False, False, False, False, False], 0),
#  176: ([False, False, True], 0),
#  177: ([True, False, False, False, False, False, False, False, False, False],
#   0),
#  178: ([False, False, True, False, False, False], 0),
#  179: ([False, True], 0),
#  180: ([False, False, False, True], 0),
#  181: ([False, False, False, False, True, False, False], 0),
#  182: ([False, False, False, False, True, False, False, False, False], 0),
#  183: ([False, False, False, True], 0),
#  184: ([True, False, False, False, False, False], 0),
#  185: ([False, True], 0),
#  186: ([False, False, True, False], 0),
#  187: ([False, False, False, False, False, True], 0),
#  188: ([True, False], 0),
#  189: ([False, True], 0),
#  190: ([True, False, False, False, False, False], 0),
#  191: ([False, True, False], 0),
#  192: ([False, False, False, True], 0),
#  193: ([False, True, False], 0),
#  194: ([False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False],
#   0),
#  195: ([False, True, False], 0),
#  196: ([True, False, False, False, False, False], 0),
#  197: ([True, False], 0),
#  198: ([False, True], 0),
#  199: ([False, True], 0),
#  200: ([False, False, False, True, False, False, False], 0),
#  201: ([False, True, False], 0),
#  202: ([False, True], 0),
#  203: ([True, False, False, True, False, False, False], 0),
#  204: ([False, False, False, True], 0),
#  205: ([False, False, False, True, False, False, False, False, False, False],
#   0),
#  206: ([False, False, False, True, False, False], 0),
#  207: ([False, True], 0),
#  208: ([False, False, False, False, True, False], 0),
#  209: ([False, False, False, True, False, False], 0),
#  210: ([True, False, True, False], 0),
#  211: ([False, True], 0),
#  212: ([False, False, False, False, False, True, False, False, False], 0),
#  213: ([False, True], 0),
#  214: ([False, False, False, True, False, False, False, False, False, False],
#   0),
#  215: ([True, True, False, False], 0),
#  216: ([False, True], 0),
#  217: ([False, True], 0),
#  218: ([False, False, False, True, False, False], 0),
#  219: ([False, False, True, False, False, False], 0),
#  220: ([True, False, False, False, False, False], 0),
#  221: ([False, True], 0),
#  222: ([False, False, False, True], 0),
#  223: ([False, True, False, False, False, False], 0),
#  224: ([False, True, False, False, False], 0),
#  225: ([False, True], 0),
#  226: ([False, False, False, True], 0),
#  227: ([True, False, False, False, False], 0),
#  228: ([False, False, True, False, False, False, False, False, False, False],
#   0),
#  229: ([False, True], 0),
#  230: ([False, False, True, False], 0),
#  231: ([False, False, False, False, True], 0),
#  232: ([False, True], 0),
#  233: ([True, False], 0),
#  234: ([False, True], 0),
#  235: ([False, False, True, False, False], 0),
#  236: ([False, False, False, False, False, False, False, False, True, False],
#   0),
#  237: ([True, False, True, False], 0),
#  238: ([True, False, False, False, False, False], 0),
#  239: ([False, True, False, False], 0),
#  240: ([False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False],
#   0),
#  241: ([True, False], 0),
#  242: ([False, True], 0),
#  243: ([False, False, True, False, True, False, False], 0),
#  244: ([False, False, True, False], 0),
#  245: ([True, False, False, False, False, False], 0),
#  246: ([True, False, False], 0),
#  247: ([False, False, True], 0),
#  248: ([True, False], 0),
#  249: ([True, False], 0),
#  250: ([False, True], 0),
#  251: ([False, False, False, True], 0),
#  252: ([False, True, False], 0),
#  253: ([False, True, False, True], 0),
#  254: ([True, False], 0),
#  255: ([False, True, False], 0),
#  256: ([False, False, False, True], 0),
#  257: ([True, False, False, False, False, False], 0),
#  258: ([False, True], 0),
#  259: ([True, False], 0),
#  260: ([False, False, True, True], 0),
#  261: ([True, False], 0),
#  262: ([False, False, False, False, True, False], 0),
#  263: ([False, True, False, False, False, False], 0),
#  264: ([False, True], 0),
#  265: ([False, True, False, False], 0),
#  266: ([False, False, True, False], 0),
#  267: ([True, False], 0),
#  268: ([False, True, False], 0),
#  269: ([True, False], 0),
#  270: ([True, False, False, False, False, False], 0),
#  271: ([False, False, True], 0),
#  272: ([True, False, False, False], 0),
#  273: ([True, False], 0),
#  274: ([False, True, False, False], 0),
#  275: ([True, False], 0),
#  276: ([False, True], 0),
#  277: ([False, False, False, False, False, True], 0),
#  278: ([False, True, False], 0),
#  279: ([False, False, False, True], 0),
#  280: ([False, True, True, False], 0),
#  281: ([False, False, False, False, False, False, True], 0),
#  282: ([False, False, False, False, True, False, False, False, False, False],
#   0),
#  283: ([True, False], 0),
#  284: ([False, True], 0),
#  285: ([False, False, False, True], 0),
#  286: ([False, False, True], 0),
#  287: ([True, False], 0),
#  288: ([False, False, False, False, False, False, False, False, False, True],
#   0),
#  289: ([False, True], 0),
#  290: ([False, True, False], 0),
#  291: ([False, False, False, True, False, False], 0),
#  292: ([True, False, False, False, False, False], 0),
#  293: ([False, False, True, False, False, False], 0),
#  294: ([False, False, True], 0),
#  295: ([False, True, False], 0),
#  296: ([True, False], 0),
#  297: ([True, False, False], 0),
#  298: ([True, False], 0),
#  299: ([False, False, False, True, False, False], 0),
#  300: ([False, True], 0),
#  301: ([False, True], 0),
#  302: ([False, False, True], 0),
#  303: ([True, False, False], 0),
#  304: ([True, False, False, False], 0),
#  305: ([False, True, False, False, False, False, False, False, False, False],
#   0),
#  306: ([False, True, False, False, False], 0),
#  307: ([False, True], 0),
#  308: ([True, False, False], 0),
#  309: ([True, False, False], 0),
#  310: ([False, True], 0),
#  311: ([False, True, False, False], 0),
#  312: ([True, False], 0),
#  313: ([True, False], 0),
#  314: ([False, True, True, False], 0),
#  315: ([True, False, False, True], 0),
#  316: ([False, True, False, False, False, False, False], 0),
#  317: ([False, False, False, False, True, False], 0),
#  318: ([False, False, True, False, False], 0),
#  319: ([False, True], 0),
#  320: ([False, True, False, False, False, False], 0),
#  321: ([False, False, False, False, False, False, True], 0),
#  322: ([False, False, False, False, True, False], 0),
#  323: ([False, False, True, False], 0),
#  324: ([True, False], 0),
#  325: ([False, True], 0),
#  326: ([False, False, False, True, False, False, False, False, False, False],
#   0),
#  327: ([False, False, False, False, False, False, True, False, False, False],
#   0),
#  328: ([False, True, False, True], 0),
#  329: ([False, True], 0),
#  330: ([False, True], 0),
#  331: ([True, False], 0),
#  332: ([False, True, False, True], 0),
#  333: ([False, False, True], 0),
#  334: ([False, True, True, False], 0),
#  335: ([False, True], 0),
#  336: ([False, False, False, True, False, False], 0),
#  337: ([False, False, True], 0),
#  338: ([True, False, False, True], 0),
#  339: ([False, False, True, True], 0),
#  340: ([False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False],
#   0),
#  341: ([False, False, False, False, False, False, False, False, True], 0),
#  342: ([True, False], 0),
#  343: ([True, False], 0),
#  344: ([True, False], 0),
#  345: ([True, False, False], 0),
#  346: ([False, False, False, False, True, False], 0),
#  347: ([False, False, False, False, True, False, False, False], 0),
#  348: ([False, False, True, False, False, False], 0),
#  349: ([True, False], 0),
#  350: ([False, True, False], 0),
#  351: ([False, True], 0),
#  352: ([False, True], 0),
#  353: ([True, False], 0),
#  354: ([False, False, False, False, False, False, True, False], 0),
#  355: ([False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False],
#   0),
#  356: ([False, False, True, True], 0),
#  357: ([False, False, False, False, True, False, False, False, False, False],
#   0),
#  358: ([False, True, False, False], 0),
#  359: ([False, False, False, False, False, False], 0),
#  360: ([True, False], 0),
#  361: ([True, False], 0),
#  362: ([False, True], 0),
#  363: ([False, False, False, True], 0),
#  364: ([False, False, False, True], 0),
#  365: ([False, False, True], 0),
#  366: ([True, False, False], 0),
#  367: ([False, False, True], 0),
#  368: ([False, False, True, False, False, False, False, False, False], 0),
#  369: ([True, False, False], 0),
#  370: ([False, False, False, False, False, False, False], 0),
#  371: ([True, False], 0),
#  372: ([False, False, False, True, False], 0),
#  373: ([False, True, False], 0),
#  374: ([False, False], 0),
#  375: ([True, False], 0),
#  376: ([False, False, False, True], 0),
#  377: ([False, False, True, False, False], 0),
#  378: ([True, False], 0),
#  379: ([False, True], 0),
#  380: ([False, False, True, False], 0),
#  381: ([True, False], 0),
#  382: ([False, False, False, False, False, False, False, False], 0),
#  383: ([False, False, False, True], 0),
#  384: ([False, False, True, False], 0),
#  385: ([False, False, True], 0),
#  386: ([True, False], 0),
#  387: ([False, True, False], 0),
#  388: ([False, True], 0),
#  389: ([False, False, False, True, False, False], 0),
#  390: ([True, False], 0),
#  391: ([False, False, False, False, True], 0),
#  392: ([False, True], 0),
#  393: ([True, False], 0),
#  394: ([False, False, False, False, False], 0),
#  395: ([False, False, False, False, False, True, False, False, False, False],
#   0),
#  396: ([False, False, True, False, False, False], 0),
#  397: ([False, True], 0),
#  398: ([False, False, False, False, False, False, True, False, False, False],
#   0),
#  399: ([True, False, False, False, False, False], 0),
#  400: ([False, True, False, False, False, False], 0),
#  401: ([False, True], 0),
#  402: ([True, False, False], 0),
#  403: ([False, False, True, True], 0),
#  404: ([False, False, True, False, False, False, False], 0),
#  405: ([False, True], 0),
#  406: ([False, True], 0),
#  407: ([True, False], 0),
#  408: ([False, False, True], 0),
#  409: ([False, True, False], 0),
#  410: ([True, False], 0),
#  411: ([True, False], 0),
#  412: ([False, False, False, False, True, False], 0),
#  413: ([True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False],
#   0),
#  414: ([False, True, False, False], 0),
#  415: ([True, False], 0),
#  416: ([False, True], 0),
#  417: ([False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False],
#   0),
#  418: ([False, False, False, False, False, False, False, True, False, False],
#   0),
#  419: ([True, False], 0),
#  420: ([False, False, False, False, False, True], 0),
#  421: ([True, False, False, False], 0),
#  422: ([True, False], 0),
#  423: ([True, False], 0),
#  424: ([True, False, False, False], 0),
#  425: ([False, True], 0),
#  426: ([False, False, False, False, False, True], 0),
#  427: ([False, True, False], 0),
#  428: ([False, False, False, False, True, False, False], 0),
#  429: ([False, True], 0),
#  430: ([False, True], 0),
#  431: ([False, False, True, False, False, False], 0),
#  432: ([False, True], 0),
#  433: ([False, False, False, False, True], 0),
#  434: ([True, False], 0),
#  435: ([False, True, True, False], 0),
#  436: ([False, False, True], 0),
#  437: ([False, False], 0),
#  438: ([False, True], 0),
#  439: ([True, False, False, False, False, False, True], 0),
#  440: ([False, False, False, True], 0),
#  441: ([False, True, False], 0),
#  442: ([False, True], 0),
#  443: ([False, True, False, True], 0),
#  444: ([True, False, False, False], 0),
#  445: ([True, False], 0),
#  446: ([False, True, False, False, False, False], 0),
#  447: ([True, False, False, False, False, False], 0),
#  448: ([False, False, False, False, False, True, False, False, False, False],
#   0),
#  449: ([False, True, False, True], 0),
#  450: ([True, False, False, False, False], 0),
#  451: ([False, False, True], 0),
#  452: ([False, False, True], 0),
#  453: ([False, False, True], 0),
#  454: ([False, True], 0),
#  455: ([True, False], 0),
#  456: ([True, False, False, False], 0),
#  457: ([False, False, True, False, True, False], 0),
#  458: ([False, False, True, False], 0),
#  459: ([False, False, False, False, True], 0),
#  460: ([True, False], 0),
#  461: ([False, False, False, False, False, False], 0),
#  462: ([False, False, True], 0),
#  463: ([False, True, False, False, False, False, False, False, False, False],
#   0),
#  464: ([False, True, False, False, False, True, False], 0),
#  465: ([True, False, False, False, False, False, False], 0),
#  466: ([False, False, True, False], 0),
#  467: ([False, False, True, False], 0),
#  468: ([False, True, False, False, False, False, False], 0),
#  469: ([True, False, False, False], 0),
#  470: ([True, False, False, False], 0),
#  471: ([True, False, False, False], 0),
#  472: ([False, False, False, True], 0),
#  473: ([False, True, False, False, False, False, False], 0),
#  474: ([False, False, False, False, False, True], 0),
#  475: ([True, False], 0),
#  476: ([True, False, False, False, False, False, False, False, False, False],
#   0),
#  477: ([True, False], 0),
#  478: ([True, False], 0),
#  479: ([False, False, False], 0),
#  480: ([False, True], 0),
#  481: ([False, True, False, True], 0),
#  482: ([True, False, False], 0),
#  483: ([False, False, True], 0),
#  484: ([False, False, False, False, False, False, True], 0),
#  485: ([False, True], 0),
#  486: ([False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False],
#   0),
#  487: ([False, True, False, False], 0),
#  488: ([False, True], 0),
#  489: ([False, True], 0),
#  490: ([False, False, False, False], 0),
#  491: ([False, True], 0)}

# %%
len(result_dic)
# Out:
# 492

# %%
# Save results as numpy dictionary:
import pickle

#with open("drive/MyDrive/data/defi-text-mine-egc-2026/val_results-gpt5.pkl", "wb") as f:
with open("drive/MyDrive/data/defi-text-mine-egc-2026/result_dic_train-gpt5_rag.pkl", "wb") as f:
  pickle.dump(result_dic,f)

f.close()

# %% [markdown]
# # Evaluation

# %%
from sklearn.metrics import f1_score

f1_list = []

for i in range(len(acronyms)):
  if i in result_dic.keys():
    y_pred = result_dic[i][0]
  else:
    y_pred = np.zeros(len(options[i]),bool)
  y_true = list(options[i].values())
  f1_list.append(f1_score(y_true,y_pred,average='binary'))

print(np.mean(f1_list))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# 0.7408536585365854
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 due to no true nor predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# My run (gpt-5) resulted in F1=0.7408536585365854

# %% [markdown]
# # Predict labels for the test set

# %% [markdown]
# Open test set

# %%
f = open("drive/MyDrive/data/defi-text-mine-egc-2026/test_v4.jsonl", "r")

ids = []
text = []
acronyms = []
options = []

for line in f:
  try:
      data = json.loads(line)

      ids.append(data["id"])

      text.append(data["text"])

      acronyms.append(data["acronym"])

      options.append(data["options"])

  except ValueError:
      print('Invalid input:',line)

f.close()

# %% [markdown]
# Perform prediction

# %%
val_results = {}
examples_to_process = [(i,0) for i in range(len(text))]

flag = False
count = 0
while examples_to_process != []:
  if count % 10 == 0:
    print(len(examples_to_process))

  item = examples_to_process.pop(0)

  # Querry the LLM
  #response = rag_chain.invoke(
  #  "Trouve ce que signifie " + acronyms[item[0]] +
  #  " dans cette phrase : " + text[item[0]] +
  #  ". Évalue les options suivantes en donnant la liste booléenne comme réponse : " + str(options[item[0]]) +
  #  ". Ne produis que la liste booléenne. N’ajoute aucune explication ni autre texte."
  #)
  response = rag_chain.invoke("Find what is "+acronyms[item[0]]+" in this phrase: "+text[item[0]]+". Evaluate the following options by giving the boolean list as an answer: "+str(options[item[0]])+". Output only the boolean list. Do not output any explanation nor other text")

  # Process the result
  labels_pred = extract_bool_list(response)

  if labels_pred != None:
    if len(labels_pred) == len(options[item[0]]):
      val_results[item[0]] = (labels_pred,item[1])
    else:
      flag = True
  else:
    flag = True

  if flag:
    if item[1] < 1:
      examples_to_process.append((item[0],item[1]+1))
    flag = False
  count+=1
# Out:
# 518
# 508
# 498
# 488
# 478
# 468
# 458
# 448
# 438
# 428
# 418
# 408
# 398
# 388
# 378
# 368
# 358
# 348
# 338
# 328
# 318
# 308
# 298
# 288
# 278
# 268
# 258
# 248
# 238
# 228
# 218
# 208
# 198
# 188
# 178
# 168
# 158
# 148
# 138
# 128
# 118
# 108
# 98
# 88
# 78
# 68
# 58
# 48
# 38
# 28
# 18
# 8

# %%
len(val_results)
# Out:
# 519

# %%
val_results
# Out:
# {0: ([False, True, False, False], 0),
#  1: ([False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False],
#   0),
#  2: ([True, False], 0),
#  3: ([False, True, False, False], 0),
#  4: ([False, False, False, True, False], 0),
#  5: ([False, False, True], 0),
#  6: ([False, False, False, False, False, False], 0),
#  7: ([False, True, True, False], 0),
#  8: ([False, False, True], 0),
#  9: ([False, False, True, False], 0),
#  10: ([False, True, False, False], 0),
#  11: ([False, True, False, False], 0),
#  12: ([False, False, False, True], 0),
#  13: ([False, True, False, False], 0),
#  14: ([True, False, False, True], 0),
#  15: ([False, True, False, False], 0),
#  16: ([False, True], 0),
#  17: ([False, False, True, False], 0),
#  18: ([False, True, True, False], 0),
#  19: ([False, False, True], 0),
#  20: ([False, True, False, False, False, False, False], 0),
#  21: ([False, True], 0),
#  22: ([False, True, False, False, False, False], 0),
#  23: ([True, True, False, False], 0),
#  24: ([True, False, False, False], 0),
#  25: ([True, False, True, False], 0),
#  26: ([False, False, True, False], 0),
#  27: ([True, False], 0),
#  28: ([True, False, False, False], 0),
#  29: ([True, False, False, True], 0),
#  30: ([False, False, False, True], 0),
#  31: ([False, False, False, False, True, False, False, False, False, False],
#   0),
#  32: ([True, False, False, False, False, False, False, False, False, False],
#   0),
#  33: ([True, False, False, False], 0),
#  34: ([False, False, False, True], 0),
#  35: ([True, False, False], 0),
#  36: ([False, True, False], 0),
#  37: ([False, True, True, False], 0),
#  38: ([False, True, False, False, False, False], 0),
#  39: ([False, True, False, False], 0),
#  40: ([False, False, True], 0),
#  41: ([False, False, False, True], 0),
#  42: ([False, True, False, False], 0),
#  43: ([False, False, False, False], 0),
#  44: ([True, False, False, False], 0),
#  45: ([False, True, True, False], 0),
#  46: ([True, False, False, True], 0),
#  47: ([False, True, False], 0),
#  48: ([True, False, False, False, False, False, False], 0),
#  49: ([False, True], 0),
#  50: ([True, True, False, False], 0),
#  51: ([False, False, True, False, False, True, False], 0),
#  52: ([True, False, False, False], 0),
#  53: ([True, True, False, False], 0),
#  54: ([True, False, False, False], 0),
#  55: ([True, False, False, True], 0),
#  56: ([True, False, False, False], 0),
#  57: ([False, False, False, True], 0),
#  58: ([False, True, True, False], 0),
#  59: ([False, False, True, False, False], 0),
#  60: ([True, False, False, False], 0),
#  61: ([False, False, True, True], 0),
#  62: ([False, False, True, False], 0),
#  63: ([False, True, False, False], 0),
#  64: ([True, True, False, False], 0),
#  65: ([False, False, False, True], 0),
#  66: ([True, False, False, False, False], 0),
#  67: ([True, True, False, False], 0),
#  68: ([False, True, False, True], 0),
#  69: ([False, False, False, True], 0),
#  70: ([False, False, False, True, False, False, False, False, False, False],
#   0),
#  71: ([False, False, False, True], 0),
#  72: ([False, True, False], 0),
#  73: ([False, True, False, True], 0),
#  74: ([False, True, False, True], 0),
#  75: ([True, False, False, False], 0),
#  76: ([False, False, True, False, False, True], 0),
#  77: ([False, True, True, False], 0),
#  78: ([False, True, False, False], 0),
#  79: ([True, False, True, False], 0),
#  80: ([True, False, False], 0),
#  81: ([False, True, False, False], 0),
#  82: ([False, False, True, False], 0),
#  83: ([False, False, False, True], 0),
#  84: ([False, False, True, False], 0),
#  85: ([False, True, False], 0),
#  86: ([True, False, True, False], 0),
#  87: ([False, False, True, False], 0),
#  88: ([True, False], 0),
#  89: ([False, True, False], 0),
#  90: ([False, False, False, True], 0),
#  91: ([False, False, False, True], 0),
#  92: ([True, False, True, False], 0),
#  93: ([True, False, False, False, False], 0),
#  94: ([False, False, True, True], 0),
#  95: ([True, False], 0),
#  96: ([True, False], 0),
#  97: ([False, False, False, True], 0),
#  98: ([True, False, False, False], 0),
#  99: ([False, False, False, False, False, True], 0),
#  100: ([True, False, False, False], 0),
#  101: ([False, False, False, False, True, False, False, False, False, False],
#   0),
#  102: ([False, False, True, False], 0),
#  103: ([True, True, False, False], 0),
#  104: ([False, True, False, False], 0),
#  105: ([False, False, True, False], 0),
#  106: ([False, True, False, False], 0),
#  107: ([False, True, False, False], 0),
#  108: ([True, False, True, False], 0),
#  109: ([False, False, False, True], 0),
#  110: ([False, True], 0),
#  111: ([False, False, True, False], 0),
#  112: ([False, True, True, False], 0),
#  113: ([False, True, False, True], 0),
#  114: ([False, True, False, True], 0),
#  115: ([False, True, False, True], 0),
#  116: ([True, False, True, False], 0),
#  117: ([True, False, False, True], 0),
#  118: ([True, True, False, False], 0),
#  119: ([False, False, True, False], 0),
#  120: ([False, False, False, True], 0),
#  121: ([True, False, False], 0),
#  122: ([False, False, True, False, False], 0),
#  123: ([False, True, False, False], 0),
#  124: ([False, False, False, True], 0),
#  125: ([False, True], 0),
#  126: ([False, False, True, False], 0),
#  127: ([False, False, True, False], 0),
#  128: ([False, False, False, False, True, False, False, False, False, False],
#   0),
#  129: ([False, False, False, True], 0),
#  130: ([False, True, True, False], 0),
#  131: ([False, True, False, True], 0),
#  132: ([False, True, False, False, False, False], 0),
#  133: ([True, False, False, True], 0),
#  134: ([False, False, False, True], 0),
#  135: ([True, True, False, False], 0),
#  136: ([False, True, False, False, False, False], 0),
#  137: ([True, False, False, False], 0),
#  138: ([True, False, False, True], 0),
#  139: ([True, False], 0),
#  140: ([True, False, False], 0),
#  141: ([False, True, False, False], 0),
#  142: ([False, True, False, False], 0),
#  143: ([False, True, False, False], 0),
#  144: ([False, True, True, False], 0),
#  145: ([True, False], 0),
#  146: ([True, False, False, True], 0),
#  147: ([False, True, False, True], 0),
#  148: ([False, False, False, False, False], 0),
#  149: ([True, False, True, False], 0),
#  150: ([False, False, True, False], 0),
#  151: ([True, False, False, False], 0),
#  152: ([True, True, False, False], 0),
#  153: ([False, False, False, False, False, False, False, True, False, False],
#   0),
#  154: ([False, False, True, False], 0),
#  155: ([True, False], 0),
#  156: ([True, False, False, False], 0),
#  157: ([False, True, True, False], 0),
#  158: ([False, False, False, True], 0),
#  159: ([False, False, False, False, True, False], 0),
#  160: ([False, True], 0),
#  161: ([False, True, False], 0),
#  162: ([False, True, False, False], 0),
#  163: ([False, False, False, True], 0),
#  164: ([False, True, False, False], 0),
#  165: ([False, False, False, False, False, False], 0),
#  166: ([True, False, True, False], 0),
#  167: ([False, True, False, False, False, False], 0),
#  168: ([True, False, False], 0),
#  169: ([False, True, False, False], 0),
#  170: ([True, False], 0),
#  171: ([True, False], 0),
#  172: ([False, True, False, False], 0),
#  173: ([False, False, False, False, False, False, True, False, False, False],
#   0),
#  174: ([False, True, False], 0),
#  175: ([False, False, False, True], 0),
#  176: ([True, False, False, False], 0),
#  177: ([False, False, False, True], 0),
#  178: ([False, False, True, False], 0),
#  179: ([True, False, True, False], 0),
#  180: ([False, False, False, False, False, False, False, False, False, True],
#   0),
#  181: ([False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False],
#   0),
#  182: ([False, False, False, True], 0),
#  183: ([False, True, False, False], 0),
#  184: ([False, False, False, False, True, True], 0),
#  185: ([True, False, False, False], 0),
#  186: ([True, False, False, False], 0),
#  187: ([True, False, False, False], 0),
#  188: ([False, False, True, False], 0),
#  189: ([False, False], 0),
#  190: ([False, True, True, False], 0),
#  191: ([False, False, False, False, False, False, False, True, False, False],
#   0),
#  192: ([False, True, False, False], 0),
#  193: ([True, True, False, False], 0),
#  194: ([False, True, False, False, False, False, False, False, False, False],
#   0),
#  195: ([True, False, False, False], 0),
#  196: ([False, False, False, True], 0),
#  197: ([False, True, False], 0),
#  198: ([False, False, False, True, False, False], 0),
#  199: ([False, False, True, False], 0),
#  200: ([True, False, False, False], 0),
#  201: ([True, False, False, True], 0),
#  202: ([False, False, True, False], 0),
#  203: ([False, False, False, True], 0),
#  204: ([False, False, True, False], 0),
#  205: ([False, False, True, False], 0),
#  206: ([False, True, False, False], 0),
#  207: ([False, False, True], 0),
#  208: ([False, False, True, True], 0),
#  209: ([True, False, False, True], 0),
#  210: ([False, False, True, False], 0),
#  211: ([True, False, False, False], 0),
#  212: ([False, True, False, False], 0),
#  213: ([False, True, False, True], 0),
#  214: ([False, False, False, True], 0),
#  215: ([False, True, False, False], 0),
#  216: ([False, False, True, True], 0),
#  217: ([False, False, False, True], 0),
#  218: ([False, True, False, True], 0),
#  219: ([False, True], 0),
#  220: ([False, True], 0),
#  221: ([False, True, True, False], 0),
#  222: ([False, False, False, True], 0),
#  223: ([False, False, False, False, False, True, False, False, False], 0),
#  224: ([False, False, True, True], 0),
#  225: ([False, True, True, False], 0),
#  226: ([False, False, False, True], 0),
#  227: ([False, True, True, False], 0),
#  228: ([False, True, False, True], 0),
#  229: ([False, True, False, True], 0),
#  230: ([False, True, False, False], 0),
#  231: ([False, False, False, False], 0),
#  232: ([True, False, False, False], 0),
#  233: ([False, False, False, True], 0),
#  234: ([False, False, True, True], 0),
#  235: ([False, True, True, False], 0),
#  236: ([True, False, False, True], 0),
#  237: ([True, False, False], 0),
#  238: ([False, False, False, True], 0),
#  239: ([False, False, True], 0),
#  240: ([False, False, True, False], 0),
#  241: ([False, True, True, False], 0),
#  242: ([False, True, False, False], 0),
#  243: ([False, False, False, True], 0),
#  244: ([False, False, True, False], 0),
#  245: ([False, False, False, True], 0),
#  246: ([True, False, False, True], 0),
#  247: ([True, False], 0),
#  248: ([False, True, True, False], 0),
#  249: ([True, False, False, True], 0),
#  250: ([False, False, False, True], 0),
#  251: ([False, False, True, False], 0),
#  252: ([False, False, True, True], 0),
#  253: ([False, True], 0),
#  254: ([False, True, False, True], 0),
#  255: ([True, False, True, False], 0),
#  256: ([False, False, True], 0),
#  257: ([False, True, False, False], 0),
#  258: ([False, True], 0),
#  259: ([False, True, False], 0),
#  260: ([False, False, True, False], 0),
#  261: ([False, False, False, True], 0),
#  262: ([False, False, False, True], 0),
#  263: ([False, True, True, False], 0),
#  264: ([True, False, False, False, False, True], 0),
#  265: ([False, False, True, False], 0),
#  266: ([False, False, False, False], 0),
#  267: ([False, True, False, False], 0),
#  268: ([False, True], 0),
#  269: ([False, True, False, False], 0),
#  270: ([False, False, False, True, False], 0),
#  271: ([False, False, False, True], 0),
#  272: ([True, False, False, False, True], 0),
#  273: ([True, True, False, False], 0),
#  274: ([True, False, True, False], 0),
#  275: ([True, True, False, False], 0),
#  276: ([False, False, True, False], 0),
#  277: ([False, False, True], 0),
#  278: ([False, False, True], 0),
#  279: ([False, True, False], 0),
#  280: ([False, True, False, False], 0),
#  281: ([True, True, False, False], 0),
#  282: ([True, False, False, True], 0),
#  283: ([True, False, False, True], 0),
#  284: ([True, False, False, True, False, False, False, False, False], 0),
#  285: ([False, True, True, False], 0),
#  286: ([False, True, False, False], 0),
#  287: ([False, True, False, True], 0),
#  288: ([False, False, False, True], 0),
#  289: ([False, False, False, False, False, False, False, False, True, False],
#   0),
#  290: ([False, False, False, False], 0),
#  291: ([True, False, False, False], 0),
#  292: ([False, False, False, False], 0),
#  293: ([True, False], 0),
#  294: ([False, True], 0),
#  295: ([False, False, True, False], 0),
#  296: ([True, False, False, False], 0),
#  297: ([True, False, True, False], 0),
#  298: ([False, False, False, False, False], 0),
#  299: ([True, False, False, False], 0),
#  300: ([True, False, False, False], 0),
#  301: ([False, True, False], 0),
#  302: ([True, True, False, False], 0),
#  303: ([False, False, False, True, False, False, False, False, False], 0),
#  304: ([False, False, False, True], 0),
#  305: ([True, False], 0),
#  306: ([False, False, False, True], 0),
#  307: ([False, False, False, False, False, False, True, False], 0),
#  308: ([False, True, False], 0),
#  309: ([True, False, False], 0),
#  310: ([True, False, False], 0),
#  311: ([False, False, False, False], 0),
#  312: ([False, False, True, False], 0),
#  313: ([False, False, False, True], 0),
#  314: ([False, False, False, False, False, False, False, False, False, True],
#   0),
#  315: ([False, True, False], 0),
#  316: ([False, False, True, False], 0),
#  317: ([True, False, False, False], 0),
#  318: ([True, False, False, False], 0),
#  319: ([False, True], 0),
#  320: ([False, False, False, False, True, True], 0),
#  321: ([False, True, True, False], 0),
#  322: ([False, False, False, False, False, False, False, True, False, False],
#   0),
#  323: ([False, True], 0),
#  324: ([True, False, False, False], 0),
#  325: ([True, False, False, False], 0),
#  326: ([False, False, False, True], 0),
#  327: ([True, False, False, False], 0),
#  328: ([True, False, False], 0),
#  329: ([False, False, True, False], 0),
#  330: ([False, False, False, False, True, False], 0),
#  331: ([True, False, False, False], 0),
#  332: ([True, True, False, False], 0),
#  333: ([True, False], 0),
#  334: ([False, False, True, True], 0),
#  335: ([True, False, False, True], 0),
#  336: ([False, False, False, True], 0),
#  337: ([False, False, True, False], 0),
#  338: ([False, True, False, False], 0),
#  339: ([False, False, True, False], 0),
#  340: ([False, True, False, True], 0),
#  341: ([False, False, True, False], 0),
#  342: ([False, False, False, False, True, False, False], 0),
#  343: ([True, False, True, False], 0),
#  344: ([True, False, False, False], 0),
#  345: ([False, True, False, False], 0),
#  346: ([False, True, False, False], 0),
#  347: ([False, False, True, False], 0),
#  348: ([False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False],
#   0),
#  349: ([False, True, False], 0),
#  350: ([False, False, True, True], 0),
#  351: ([False, False, True], 0),
#  352: ([False, False, True, False, False, False], 0),
#  353: ([False, False, True, False], 0),
#  354: ([False, False, False, True, False, False], 0),
#  355: ([False, False, False, True, False, False, False, False], 0),
#  356: ([True, False, False, True], 0),
#  357: ([False, True], 0),
#  358: ([False, True, False, True], 0),
#  359: ([False, False, False, True], 0),
#  360: ([False, True, False, True], 0),
#  361: ([True, False, False, True], 0),
#  362: ([True, False, False, False], 0),
#  363: ([False, True, False, False], 0),
#  364: ([True, False, False, True], 0),
#  365: ([False, False, True, False], 0),
#  366: ([True, False], 0),
#  367: ([False, False, True, False], 0),
#  368: ([False, False, False, True], 0),
#  369: ([True, False], 0),
#  370: ([False, False, True, True], 0),
#  371: ([True, True, False], 0),
#  372: ([False, False, False, False], 0),
#  373: ([True, False, False, False], 0),
#  374: ([False, False, False, True], 0),
#  375: ([False, True, False, False], 0),
#  376: ([False, True, False, False], 0),
#  377: ([False, True, False], 0),
#  378: ([False, True, False, True], 0),
#  379: ([True, False, False, True], 0),
#  380: ([False, True], 0),
#  381: ([True, False, False, False], 0),
#  382: ([False, True], 0),
#  383: ([True, False, False, False], 0),
#  384: ([False, False, True, True], 0),
#  385: ([False, True, False], 0),
#  386: ([False, False, False, True, False, False], 0),
#  387: ([True, False, False, False], 0),
#  388: ([False, True, False, True], 0),
#  389: ([False, False, False, True], 0),
#  390: ([False, False, True, False], 0),
#  391: ([False, False, True], 0),
#  392: ([False, True, False, False, False, False, False, False, False, False],
#   0),
#  393: ([False, True, False, False], 0),
#  394: ([True, False, False], 0),
#  395: ([True, False, False, False], 0),
#  396: ([False, True, False, False], 0),
#  397: ([False, True, False, False, False, False], 0),
#  398: ([False, True, False, False], 0),
#  399: ([True, False, False, False], 0),
#  400: ([True, False, False, False, False, False], 0),
#  401: ([False, True], 0),
#  402: ([False, False, True, False], 0),
#  403: ([True, False, False, False, False, False, False], 0),
#  404: ([True, False], 0),
#  405: ([True, False, False], 0),
#  406: ([False, True, False, False, False, False], 0),
#  407: ([True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    True,
#    False,
#    False,
#    False],
#   0),
#  408: ([False, True, False, False], 0),
#  409: ([False, True, False, False], 0),
#  410: ([False, False, True], 0),
#  411: ([False, False, True, False], 0),
#  412: ([False, False, False, True, False], 0),
#  413: ([False, True, False, False], 0),
#  414: ([True, True, False, False], 0),
#  415: ([False, False, False, True], 0),
#  416: ([True, False, False, False], 0),
#  417: ([False, False, False, False, True], 0),
#  418: ([False, True, False, False], 0),
#  419: ([False, False, True, False, False], 0),
#  420: ([False, False, True, False], 0),
#  421: ([False, True, False], 0),
#  422: ([False, False, True, False], 0),
#  423: ([False, False, False, True], 0),
#  424: ([False, False, True, False, False, False], 0),
#  425: ([True, False, False, False], 0),
#  426: ([False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False],
#   0),
#  427: ([False, True, False, True], 0),
#  428: ([True, False, False, False], 0),
#  429: ([True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False],
#   0),
#  430: ([True, False, False, False], 0),
#  431: ([False, False, True], 0),
#  432: ([False, True], 0),
#  433: ([True, False], 0),
#  434: ([False, False, True, False], 0),
#  435: ([False, True, True], 0),
#  436: ([True, False, False, True], 0),
#  437: ([False, True, False, True], 0),
#  438: ([True, True, False, False], 0),
#  439: ([False, True, False, False], 0),
#  440: ([True, False, False, True], 0),
#  441: ([False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False],
#   0),
#  442: ([False, True, True, False], 0),
#  443: ([True, False, False, True], 0),
#  444: ([False, True, True, False, False, False, False], 0),
#  445: ([False, True], 0),
#  446: ([False, True, False], 0),
#  447: ([False, True], 0),
#  448: ([False, False, False, False, False, False], 0),
#  449: ([True, True, False, False], 0),
#  450: ([False, False, False, True, False, False, False], 0),
#  451: ([True, False], 0),
#  452: ([False, False, True, False], 0),
#  453: ([False, True, False, False], 0),
#  454: ([True, False, False, False], 0),
#  455: ([False, True, True, False], 0),
#  456: ([False, True, False, False], 0),
#  457: ([True, False, False, True], 0),
#  458: ([False, True, False], 0),
#  459: ([False, False, True, True], 0),
#  460: ([True, False, False, False], 0),
#  461: ([False, False, True, False], 0),
#  462: ([False, True, False, False, False, False, False, False], 0),
#  463: ([True, False, False, False, False, False, False, False, False, False],
#   0),
#  464: ([False, False, True, True], 0),
#  465: ([True, False, False, False], 0),
#  466: ([False,
#    True,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True],
#   0),
#  467: ([False, False, True, False], 0),
#  468: ([False, True, False, True], 0),
#  469: ([True, False, False, False], 0),
#  470: ([False, True], 0),
#  471: ([False, False, False, False, False, False, True], 0),
#  472: ([True, False, True, False], 0),
#  473: ([True, False, False, False], 0),
#  474: ([True, False, False, True], 0),
#  475: ([True, False, False, True], 0),
#  476: ([False, False, True, False, False, False, False, False, False, False],
#   0),
#  477: ([False, True], 0),
#  478: ([True, False], 0),
#  479: ([False, True, False], 0),
#  480: ([False, True, True, False], 0),
#  481: ([False, False, False, False], 0),
#  482: ([True, True, False, False], 0),
#  483: ([False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False],
#   0),
#  484: ([True, True, False, False], 0),
#  485: ([False, False, False, True], 0),
#  486: ([False, False, True, False], 0),
#  487: ([False, True, False, False], 0),
#  488: ([False, True, True, False], 0),
#  489: ([False, False, True], 0),
#  490: ([False, False, False, True], 0),
#  491: ([False, False, True, False], 0),
#  492: ([True, False, False], 0),
#  493: ([False, False, False, True], 0),
#  494: ([False, False, True, False], 0),
#  495: ([False, True, False, False, False, False, False], 0),
#  496: ([False, True], 0),
#  497: ([False, False, True, True], 0),
#  498: ([False, False, True], 0),
#  499: ([False, False, True, False, False, False], 0),
#  500: ([False, True, True, False], 0),
#  501: ([False, True, True, False], 0),
#  502: ([True, True, False], 0),
#  503: ([False, False, True, False], 0),
#  504: ([False, False, True, False], 0),
#  505: ([True, False, False, False, False, False, False, False, False, False],
#   0),
#  506: ([False, True, False], 0),
#  507: ([False, False, True, False], 0),
#  508: ([False, True, False], 0),
#  509: ([False, True, False, False], 0),
#  510: ([False, False, False, True], 0),
#  511: ([False, False, True, False], 0),
#  512: ([False, False, False, True], 0),
#  513: ([False, False, False, True, False, False], 0),
#  514: ([False, False, False, False, True, False], 0),
#  515: ([False, True, False, False], 0),
#  516: ([False, False, True, False, False, False], 0),
#  517: ([False, True, True, False], 0),
#  518: ([False, False, False, True], 0)}

# %% [markdown]
# Save to the CSV file

# %%
import csv

f_out = open('drive/MyDrive/data/defi-text-mine-egc-2026/submission_gpt5_rag.csv', 'w', newline='', encoding='UTF8')

tab = csv.writer(f_out,delimiter=',')

header = ['id','prediction']
tab.writerow(header)

for id in ids:
    if id not in val_results.keys():
      tab.writerow([str(id),'[]'])
    else:
      tab.writerow([str(id),str([i for i, val in enumerate(val_results[id][0]) if val])])

f_out.close()
